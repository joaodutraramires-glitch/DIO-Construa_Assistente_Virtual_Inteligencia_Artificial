# %%
# !pip install -q google-genai

# %%
base_conhecimento = {
    "moradia": {
        "percentual_maximo": 35,
        "descricao": "Aluguel, financiamento e condomínio."
    },
    "alimentacao": {
        "percentual_maximo": 30,
        "descricao": "Gastos com alimentação."
    },
    "transporte": {
        "percentual_maximo": 15,
        "descricao": "Gastos com transporte."
    },
    "lazer": {
        "percentual_maximo": 10,
        "descricao": "Gastos com lazer."
    },
    "streaming": {
        "percentual_maximo": 5,
        "descricao": "Assinaturas e streaming."
    }
}

# %%
from google import genai
from google.colab import userdata

api_key_colab = userdata.get("GEMINI_ASS")

client = genai.Client(
    api_key=api_key_colab
)

# %%
print("===== MIA - Monitor Inteligente de Gastos com IA =====")

renda = float(input("Informe sua renda mensal: R$ "))

moradia = float(input("Gasto com moradia: R$ "))
alimentacao = float(input("Gasto com alimentação: R$ "))
transporte = float(input("Gasto com transporte: R$ "))
lazer = float(input("Gasto com lazer: R$ "))
streaming = float(input("Gasto com streaming: R$ "))
# Out:
# ===== MIA - Monitor Inteligente de Gastos com IA =====
# Informe sua renda mensal: R$ 3000
# Gasto com moradia: R$ 1000
# Gasto com alimentação: R$ 500
# Gasto com transporte: R$ 200
# Gasto com lazer: R$ 150
# Gasto com streaming: R$ 60

# %%
perc_moradia = (moradia / renda) * 100
perc_alimentacao = (alimentacao / renda) * 100
perc_transporte = (transporte / renda) * 100
perc_lazer = (lazer / renda) * 100
perc_streaming = (streaming / renda) * 100

# %%
total_gastos = (
    moradia +
    alimentacao +
    transporte +
    lazer +
    streaming
)

saldo = renda - total_gastos

percentual_comprometido = (
    total_gastos / renda
) * 100

# %%
if saldo < 0:
    classificacao = "Crítica"

elif saldo < renda * 0.10:
    classificacao = "Atenção"

elif saldo < renda * 0.30:
    classificacao = "Boa"

else:
    classificacao = "Excelente"

# %%
alertas = []

if perc_moradia > 35:
    alertas.append("Moradia acima do recomendado.")

if perc_alimentacao > 30:
    alertas.append("Alimentação acima do recomendado.")

if perc_transporte > 15:
    alertas.append("Transporte acima do recomendado.")

if perc_lazer > 10:
    alertas.append("Lazer acima do recomendado.")

if perc_streaming > 5:
    alertas.append("Streaming acima do recomendado.")

# %%
prompt = f"""
Você é MIA (Monitor Inteligente de Gastos com IA).

Sua função é analisar os gastos do usuário e fornecer uma avaliação financeira clara.

REGRAS:

- Não invente informações.
- Não recomende investimentos.
- Seja objetiva e educativa.
- Explique os cálculos de forma simples.
- Considere os limites recomendados.

LIMITES:

Moradia: até 35%
Alimentação: até 30%
Transporte: até 15%
Lazer: até 10%
Streaming: até 5%

DADOS DO USUÁRIO

Renda: R$ {renda:.2f}

Moradia:
R$ {moradia:.2f}
({perc_moradia:.1f}%)

Alimentação:
R$ {alimentacao:.2f}
({perc_alimentacao:.1f}%)

Transporte:
R$ {transporte:.2f}
({perc_transporte:.1f}%)

Lazer:
R$ {lazer:.2f}
({perc_lazer:.1f}%)

Streaming:
R$ {streaming:.2f}
({perc_streaming:.1f}%)

Total de gastos:
R$ {total_gastos:.2f}

Saldo restante:
R$ {saldo:.2f}

Percentual comprometido da renda:
{percentual_comprometido:.1f}%

Classificação preliminar:
{classificacao}

Alertas encontrados:
{alertas if alertas else "Nenhum alerta identificado"}

Forneça:

1. Resumo financeiro.
2. Avaliação da saúde financeira.
3. Justificativa da classificação.
4. Gastos acima do recomendado.
5. Sugestões práticas para melhorar a organização financeira.
6. Conclusão final.
"""

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt
)

print(response.text)
# Out:
# Olá! Eu sou MIA, seu Monitor Inteligente de Gastos com IA. Vamos analisar seus dados financeiros para fornecer uma avaliação clara e objetiva.
#
# ---
#
# ### Análise Financeira por MIA
#
# **1. Resumo Financeiro**
#
# *   **Renda Mensal:** R$ 3.000,00
# *   **Total de Gastos:** R$ 1.910,00
# *   **Saldo Restante:** R$ 1.090,00
# *   **Percentual da Renda Comprometido:** 63,7%
#
# **Detalhamento dos Gastos:**
#
# *   **Moradia:** R$ 1.000,00 (33,3% da renda) - Limite recomendado: até 35%
# *   **Alimentação:** R$ 500,00 (16,7% da renda) - Limite recomendado: até 30%
# *   **Transporte:** R$ 200,00 (6,7% da renda) - Limite recomendado: até 15%
# *   **Lazer:** R$ 150,00 (5,0% da renda) - Limite recomendado: até 10%
# *   **Streaming:** R$ 60,00 (2,0% da renda) - Limite recomendado: até 5%
#
# **2. Avaliação da Saúde Financeira**
#
# Sua saúde financeira é **muito boa**. Todos os seus gastos por categoria estão bem dentro dos limites recomendados, e você consegue manter uma parte significativa da sua renda como saldo restante.
#
# **3. Justificativa da Classificação**
#
# A classificação "Excelente" é justificada porque você demonstra um controle exemplar sobre suas finanças.
#
# *   **Controle por Categoria:** Cada categoria de gasto (Moradia, Alimentação, Transporte, Lazer e Streaming) está abaixo ou no limite máximo recomendado, indicando um gerenciamento consciente de cada despesa.
#     *   Exemplo: Seus gastos com Moradia são de 33,3%, abaixo do limite de 35%.
#     *   Exemplo: Seus gastos com Alimentação são de 16,7%, bem abaixo do limite de 30%.
# *   **Alto Saldo Restante:** Com um saldo de R$ 1.090,00 (36,3% da sua renda total) após cobrir todas as despesas essenciais e de lazer, você possui uma excelente capacidade de poupança e para alcançar objetivos financeiros futuros.
# *   **Renda Comprometida Saudável:** O percentual de 63,7% da renda comprometida com gastos é saudável, pois permite que mais de um terço da sua renda fique disponível.
#
# **4. Gastos Acima do Recomendado**
#
# Nenhum dos seus gastos por categoria está acima dos limites recomendados. Todos estão bem gerenciados.
#
# **5. Sugestões Práticas para Melhorar a Organização Financeira**
#
# Embora sua situação seja excelente, algumas sugestões podem otimizar ainda mais sua organização:
#
# *   **Automatize sua Poupança:** Com R$ 1.090,00 de saldo restante, você tem uma grande oportunidade de construir uma reserva. Considere automatizar a transferência de uma parte desse valor para uma conta de poupança ou aplicação separada assim que receber sua renda. Isso garante que a poupança seja prioritária.
# *   **Defina Metas para o Saldo Restante:** Ter um saldo tão positivo é ótimo, mas ter um propósito para ele é ainda melhor. Pense em objetivos como:
#     *   Formar uma reserva de emergência (idealmente de 3 a 6 meses dos seus gastos totais).
#     *   Planos de médio ou longo prazo (ex: compra de um bem, cursos, viagens).
# *   **Revisão Periódica:** Mantenha o hábito de revisar seus gastos e seu orçamento regularmente (mensal ou trimestralmente). Isso ajuda a identificar qualquer mudança no seu padrão de consumo e a fazer ajustes conforme necessário, mantendo seu controle financeiro.
# *   **Explore o Potencial de Otimização (Opcional):** Embora seus gastos estejam dentro do limite, você tem espaço em categorias como Alimentação e Lazer. Se desejar acelerar ainda mais seus objetivos financeiros, poderia verificar se há pequenas otimizações possíveis, mas sem comprometer seu bem-estar, já que sua situação atual é sólida.
#
# **6. Conclusão Final**
#
# Você está em uma posição financeira invejável, gerenciando seus gastos de forma muito eficaz e mantendo um saldo positivo substancial. Continue com essa disciplina e considere usar o excedente de forma estratégica para construir uma base financeira ainda mais sólida para o futuro. Parabéns pelo excelente controle financeiro!
